# %% [raw]
# Seaborn in comparisent with Matplotlib

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
#создаем данные
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)

# %%
#рисуем график, используя параметры Matplotlib по умолчанию
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left')

# %% [raw]
# Теперь посмотрим, как можно сделать это с помощью Seaborn. Помимо множества собственных высокоуровневых функций построения графиков библиотеки Seaborn, она может также перекрывать параметры по умолчанию библиотеки Matplotlib, благодаря чему применение даже более простых сценариев Matplotlib приводит к на- много лучшему результату.

# %%
import seaborn as sns
sns.set()

# %%
#Тот же самый код для построения графика, что и выше!
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left')

# %% [raw]
# Анализ графиков Seaborn
#
# Основная идея библиотеки Seaborn — предоставление высокоуровневых команд для создания множества различных типов графиков, удобных для исследования статистических данных и даже подгонки статистических моделей.

# %% [raw]
# Гистограммы, KDE и плотности

# %%
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], 
                                     size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])

for col in 'xy':
    plt.hist(data[col], normed=True, alpha=0.5)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.

# %% [raw]
# Вместо гистограммы можно получить гладкую оценку распределения путем ядерной оценки плотности распределения (KDE-Kernel Density Estimation), которую Seaborn выполняет с помощью функции sns.kdeplot

# %%
for col in 'xy':
    sns.kdeplot(data[col], shade=True)

# %% [raw]
# С помощью функции distplot можно сочетать гистограммы и KDE

# %%
sns.distplot(data['x'])
sns.distplot(data['y'])

# %% [raw]
# Если передать функции kdeplot весь двумерный набор данных, можно получить
# двумерную визуализацию данных

# %%
sns.kdeplot(data)
#sns.kdeplot(data['x'], data['y'])  - should be used in new version

# %% [raw]
# Посмотреть на совместное распределение и частные распределения можно, вос- пользовавшись функцией sns.jointplot. Для этого графика мы зададим стиль с белым фоном

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='kde')
    
#График совместного распределения с двумерным графиком оценки плотности:

# %% [raw]
# Функции jointplot можно передавать и другие параметры, например можно воспользоваться гистограммой на базе шестиугольников

# %%
with sns.axes_style('white'):
    sns.jointplot('x', 'y', data, kind='hex')

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [raw]
# Визуализация многомерных зависимостей между выборками сводится к вызову функции sns.pairplot

# %%
sns.pairplot(iris, hue='species', size=2.5, diag_kind='hist')
#Параметр 'size' переименован в 'height'
#diag_kind{‘auto’, ‘hist’, ‘kde’, None}, optional
#Kind of plot for the diagonal subplots. The default depends on whether "hue" is used or not.

# %%
iris['sepal_length'].max()
# Out:
# 7.9

# %% [raw]
# Фасетные гистограммы
#
# Иногда оптимальный способ представления данных — гистограммы подмножеств. Функция FacetGrid библиотеки Seaborn делает эту задачу элементарной. Рас- смотрим данные, отображающие суммы, которые персонал ресторана получает в качестве чаевых, в зависимости от данных различных индикаторов

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_pct'] = 100 * tips['tip'] / tips['total_bill']

grid = sns.FacetGrid(tips, row='sex', col='time', margin_titles=True)
grid.map(plt.hist, "tip_pct", bins=np.linspace(0, 40, 15))

# %% [raw]
# Графики факторов
#
# Графики факторов тоже подходят для подобных визуализаций. Они позволяют просматривать распределение параметра по интервалам, задаваемым посредством любого другого параметра

# %%
with sns.axes_style(style='ticks'):
    g = sns.factorplot("day", "total_bill", "sex", data=tips,
                       kind="box")
    g.set_axis_labels("Day", "Total Bill") #День, Итого

#The `factorplot` function has been renamed to `catplot`. 
#The original name will be removed in a future release. 
#Please update your code. 
#Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

#Пример графика факторов со сравнением распределений
#при различных дискретных факторах
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [raw]
# Совместные распределения
#
# Аналогично графикам пар, которые мы рассматривали ранее, мы можем воспользоваться функцией sns.jointplot для отображения совместного распределения между различными наборами данных, а также соответствующих частных распределений

# %%
with sns.axes_style('white'):
    sns.jointplot("total_bill", "tip", data=tips, kind="hex")

# %% [raw]
# График совместного распределения позволяет даже выполнять автоматическую
# ядерную оценку плотности распределения и регрессию

# %%
sns.jointplot("total_bill", "tip", data=tips, kind="reg")

# %% [raw]
# Столбчатые диаграммы
#
# Графики временных рядов можно строить с помощью функции sns.factorplot

# %%
planets = sns.load_dataset('planets')
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
with sns.axes_style('white'):
    #sns.factplot has been renamed to catplot
    g = sns.catplot("year", data=planets, aspect=2,
                       kind="count", color='steelblue')
    g.set_xticklabels(step=5)

# %%
with sns.axes_style('white'):
    g = sns.factorplot("year", data=planets, aspect=4.0, kind='count',
                       hue='method', order=range(2001, 2015))
    g.set_ylabels('Number of Planets Discovered')

# %% [raw]
# Пример: Вермя прохождения марафона

# %%
data = pd.read_csv('/Users/gleb/Downloads/marathon-data-master/marathon-data.csv')
data.head()
# Out:
#    age gender     split     final
# 0   33      M  01:05:38  02:08:51
# 1   32      M  01:06:26  02:09:28
# 2   31      M  01:06:49  02:10:42
# 3   38      M  01:06:16  02:13:45
# 4   31      M  01:06:32  02:13:59

# %%
data.dtypes
# Out:
# age        int64
# gender    object
# split     object
# final     object
# dtype: object

# %%
from pandas import datetools
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-63-3ae5f29bf876> in <module>
# ----> 1 from pandas import datetools
#
# ImportError: cannot import name 'datetools' from 'pandas' (/opt/anaconda3/lib/python3.7/site-packages/pandas/__init__.py)

# %%
def convert_time(s):
    #h, m, s = map(int, s.split(':'))
    return pd.to_timedelta(s)
data = pd.read_csv('/Users/gleb/Downloads/marathon-data-master/marathon-data.csv',
                   converters={'split': convert_time,
                               'final': convert_time})

# %%
data.head()
# Out:
#    age gender    split    final
# 0   33      M 01:05:38 02:08:51
# 1   32      M 01:06:26 02:09:28
# 2   31      M 01:06:49 02:10:42
# 3   38      M 01:06:16 02:13:45
# 4   31      M 01:06:32 02:13:59

# %%
data['split_sec'] = data['split'].astype(int) / 1E9
data['final_sec'] = data['final'].astype(int) / 1E9
data.head()
# Out:
#    age gender    split    final  split_sec  final_sec
# 0   33      M 01:05:38 02:08:51     3938.0     7731.0
# 1   32      M 01:06:26 02:09:28     3986.0     7768.0
# 2   31      M 01:06:49 02:10:42     4009.0     7842.0
# 3   38      M 01:06:16 02:13:45     3976.0     8025.0
# 4   31      M 01:06:32 02:13:59     3992.0     8039.0

# %%
with sns.axes_style('white'):
    g = sns.jointplot("split_sec", "final_sec", data, kind='hex')
    g.ax_joint.plot(np.linspace(4000, 16000),
                    np.linspace(8000, 32000), ':k')

# %%
data['split_frac'] = 1-2 * data['split_sec'] / data['final_sec']
data.head()
# Out:
#    age gender    split    final  split_sec  final_sec  split_frac
# 0   33      M 01:05:38 02:08:51     3938.0     7731.0   -0.018756
# 1   32      M 01:06:26 02:09:28     3986.0     7768.0   -0.026262
# 2   31      M 01:06:49 02:10:42     4009.0     7842.0   -0.022443
# 3   38      M 01:06:16 02:13:45     3976.0     8025.0    0.009097
# 4   31      M 01:06:32 02:13:59     3992.0     8039.0    0.006842

# %%
sns.distplot(data['split_frac'], kde=False)
plt.axvline(0, color="k", linestyle="--")

# %%
sum(data.split_frac < 0)
# Out:
# 251

# %% [raw]
# Из почти 40 000 участников только 250 человек распределяют свои силы на марафонской дистанции в обратной пропорции.
# Выясним, существует ли какая-либо корреляция между коэффициентом распре- деления сил и другими переменными. Для построения графиков всех этих корре- ляций мы воспользуемся функцией pairgrid

# %%
g = sns.PairGrid(data, vars=['age', 'split_sec', 'final_sec', 'split_frac'],
                 hue='gender', palette='RdBu_r')

g.map(plt.scatter, alpha=0.8 )
#for i, ax in enumerate(g.fig.axes):
    #ax.set_xticklabels(ax.get_xticklabels(), rotation = 45)
      
g.add_legend()

# %% [raw]
# Кроме того, представляет интерес различие между мужчинами и женщинами. Рассмотрим гистограмму коэффициентов распределения сил для этих двух групп

# %%
sns.kdeplot(data.split_frac[data.gender=="M"],
            label='men', shade=True)
sns.kdeplot(data.split_frac[data.gender=="W"],
            label='women', shade=True)
plt.xlabel('split_frac')
# Out:
# Text(0.5, 0, 'split_frac')

# %% [raw]
# Удобный способ сравнения распределений — использование так называемой скрипичной диаграммы

# %%
sns.violinplot("gender", "split_frac", data=data,
               palette=["lightblue", "lightpink"])

# %%
data['age_dec'] = data.age.map(lambda age: 10 * (age//10))
data.head()
# Out:
#    age gender    split    final  split_sec  final_sec  split_frac  age_dec
# 0   33      M 01:05:38 02:08:51     3938.0     7731.0   -0.018756       30
# 1   32      M 01:06:26 02:09:28     3986.0     7768.0   -0.026262       30
# 2   31      M 01:06:49 02:10:42     4009.0     7842.0   -0.022443       30
# 3   38      M 01:06:16 02:13:45     3976.0     8025.0    0.009097       30
# 4   31      M 01:06:32 02:13:59     3992.0     8039.0    0.006842       30

# %%
men = (data.gender == 'M')
women = (data.gender == 'W')
with sns.axes_style(style=None):
    sns.violinplot("age_dec", "split_frac", hue="gender", data=data,
                   split=True, inner="quartile",
                   palette=["lightblue", "lightpink"])

# %%
(data.age > 80).sum()
# Out:
# 7

# %% [raw]
# Возвращаясь к мужчинам с обратным распределением сил: кто эти бегуны? Су- ществует ли корреляция между этим обратным распределением сил и быстрым прохождением марафона в целом? Мы можем легко построить соответствующий график. Воспользуемся функцией regplot, автоматически выполняющей подбор параметров линейной регрессии для имеющихся данных

# %%
g = sns.lmplot('final_sec', 'split_frac', col='gender', data=data,
               markers=".", scatter_kws=dict(color='c'))
g.map(plt.axhline, y=0.1, color="k", ls=":")
